# %%
import time

from osm_runner import Runner  # pip install osm-runner
import pandas as pd

from arcgis.features import FeatureLayer, GeoAccessor, GeoSeriesAccessor
from arcgis.geoenrichment import enrich
from arcgis import dissolve_boundaries
from arcgis.geometry import project
from arcgis.gis import GIS

# %%
from arcgis.features import FeatureLayer, GeoAccessor, GeoSeriesAccessor
from arcgis.geoenrichment import enrich
from arcgis import dissolve_boundaries
from arcgis.geometry import project
from arcgis.gis import GIS

# %% [markdown]
# # community_centre

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="community_centre"](area);
 way["amenity"="community_centre"](area);
 rel["amenity"="community_centre"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
community_centre_data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in community_centre_data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('community_centre in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Bahnhof

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["name"="Bahnhof"](area);
 way["name"="Bahnhof"](area);
 rel["name"="Bahnhof"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Bahnhof in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
#  # College

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="college"](area);
 way["amenity"="college"](area);
 rel["amenity"="college"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.57 93a4d346',
#  'osm3s': {'timestamp_osm_base': '2021-11-24T18:05:52Z',
#   'timestamp_areas_base': '2021-11-24T17:32:34Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 86745776,
#    'lat': 51.4360641,
#    'lon': 6.6526371,
#    'tags': {'addr:city': 'Moers',
#     'addr:country': 'DE',
#     'addr:housenumber': '71',
#     'addr:postcode': '47447',
#     'addr:street': 'Waldstraße',
#     'amenity': 'college',
#     'name': 'Verkehrsübungsplatz',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 146291194,
#    'lat': 52.6375782,
#    'lon': 9.2142393,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule',
#     'operator': 'Landkreis Nienburg/Weser',
#     'operator:type': 'public',
#     'phone': '+49 5021 967-600',
#     'website': 'https://www.vhs-nienburg.de/'}},
#   {'type': 'node',
#    'id': 246855962,
#    'lat': 53.1603601,
#    'lon': 8.2128377,
#    'tags': {'addr:city': 'Oldenburg',
#     'addr:housenumber': '132',
#     'addr:postcode': '26121',
#     'addr:street': 'Ehnernstraße',
#     'amenity': 'college',
#     'email': 'info@bztg-oldenburg.de',
#     'name': 'Bildungszentrum für Technik und Gestaltung',
#     'operator': 'Stadt Oldenburg',
#     'phone': '+49 441 983770',
#     'website': 'www.bztg-oldenburg.de'}},
#   {'type': 'node',
#    'id': 252401371,
#    'lat': 51.4968401,
#    'lon': 7.1033502,
#    'tags': {'amenity': 'college',
#     'name': 'Kirchliches Bildungszentrum für Gesundheitsberufe im Revier'}},
#   {'type': 'node',
#    'id': 255356115,
#    'lat': 51.5139439,
#    'lon': 7.1185794,
#    'tags': {'addr:city': 'Gelsenkirchen',
#     'addr:housenumber': '158-160',
#     'addr:postcode': '45888',
#     'addr:street': 'Wanner Straße',
#     'amenity': 'college',
#     'name': 'Fachhochschule für öffentliche Verwaltung (FHöV) NRW (Campus Gelsenkirchen)',
#     'wheelchair:description': 'Weitere Informationen bzgl. der Barrierefreiheit finden Sie unter folgenden Link: http://www.kombabb-internetportal-nrw.de/plugin.php?menuid=6&template=mv/templates/mv_show_front.html&mv_id=1&extern_meta=x&mv_content_id=29'}},
#   {'type': 'node',
#    'id': 255721240,
#    'lat': 47.6675507,
#    'lon': 9.1709292,
#    'tags': {'addr:city': 'Konstanz',
#     'addr:country': 'DE',
#     'addr:housenumber': '8',
#     'addr:postcode': '78462',
#     'addr:street': 'Alfred-Wachtel-Straße',
#     'addr:suburb': 'Altstadt',
#     'alt_name': 'Hochschule für Technik, Wirtschaft und Gestaltung, Konstanz',
#     'amenity': 'college',
#     'internet_access': 'wlan',
#     'internet_access:ssid': 'Eduroam',
#     'name': 'HTWG Konstanz',
#     'phone': '+4975312060',
#     'website': 'https://www.htwg-konstanz.de/',
#     'wheelchair': 'limited',
#     'wikidata': 'Q1622118',
#     'wikipedia': 'de:Hochschule Konstanz Technik, Wirtschaft und Gestaltung'}},
#   {'type': 'node',
#    'id': 257683215,
#    'lat': 51.3169013,
#    'lon': 13.2884814,
#    'tags': {'addr:housenumber': '6',
#     'addr:postcode': '01591',
#     'addr:street': 'Rittergutstraße',
#     'amenity': 'college',
#     'name': 'Berufsakademie Riesa'}},
#   {'type': 'node',
#    'id': 258988967,
#    'lat': 51.1775219,
#    'lon': 6.456374,
#    'tags': {'amenity': 'college',
#     'name': 'Berufskolleg der Ev. Stiftung Hephata',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 259122447,
#    'lat': 51.4186717,
#    'lon': 7.0279686,
#    'tags': {'amenity': 'college',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Dore-Jakob-Berufskolleg'}},
#   {'type': 'node',
#    'id': 259770343,
#    'lat': 47.7081699,
#    'lon': 11.3980522,
#    'tags': {'addr:city': 'Benediktbeuern',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '83671',
#     'addr:street': 'Don-Bosco-Straße',
#     'amenity': 'college',
#     'name': 'Katholische Stiftungshochschule Benediktbeuern',
#     'short_name': 'KSFH Benediktbeuern',
#     'website': 'https://www.ksh-muenchen.de/hochschule/campus-benediktbeuern/',
#     'wheelchair': 'limited',
#     'wikidata': 'Q1632429',
#     'wikipedia': 'de:Katholische Stiftungshochschule München'}},
#   {'type': 'node',
#    'id': 263686513,
#    'lat': 49.998868,
#    'lon': 8.2663196,
#    'tags': {'alt_name': 'Maison de France',
#     'amenity': 'college',
#     'name': 'Institut Français Mayence',
#     'source': 'http://www.institutfrancais.de/mainz/uber-uns-464/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 264788724,
#    'lat': 50.9488209,
#    'lon': 6.9465501,
#    'tags': {'addr:city': 'Köln',
#     'addr:country': 'DE',
#     'addr:housename': 'forum im MediaPark',
#     'addr:housenumber': '4c',
#     'addr:postcode': '50670',
#     'addr:street': 'Im Mediapark',
#     'amenity': 'college',
#     'layer': '1',
#     'name': 'Hochschule Fresenius (Campus Köln)',
#     'source': 'photography',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Weitere Informationen bzgl. der Barrierefreiheit finden Sie unter folgenden Link: http://www.kombabb-internetportal-nrw.de/plugin.php?menuid=6&template=mv/templates/mv_show_front.html&mv_id=1&extern_meta=x&mv_content_id=63'}},
#   {'type': 'node',
#    'id': 267040604,
#    'lat': 49.427511,
#    'lon': 8.6857082,
#    'tags': {'amenity': 'college',
#     'name': 'Musik- und Singschule Heidelberg',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 269971190,
#    'lat': 51.0042426,
#    'lon': 7.5759684,
#    'tags': {'amenity': 'college',
#     'name': 'Kreisvolkshochschule Oberbergischer Kreis'}},
#   {'type': 'node',
#    'id': 271219263,
#    'lat': 48.5189862,
#    'lon': 9.0600983,
#    'tags': {'addr:city': 'Tübingen',
#     'addr:housenumber': '12',
#     'addr:postcode': '72074',
#     'addr:street': 'Gartenstraße',
#     'amenity': 'college',
#     'link': 'http://www.kirchenmusikhochschule.de/',
#     'name': 'Hochschule für Kirchenmusik',
#     'wikidata': 'Q1380220',
#     'wikimedia_commons': 'File:Suevia Tübingen 2009-11-07 bb.jpg',
#     'wikipedia': 'de:Evangelische Hochschule für Kirchenmusik Tübingen'}},
#   {'type': 'node',
#    'id': 271729550,
#    'lat': 50.7228587,
#    'lon': 12.4686249,
#    'tags': {'addr:city': 'Zwickau',
#     'addr:country': 'DE',
#     'addr:housenumber': '72',
#     'addr:postcode': '08060',
#     'addr:street': 'Werdauer Straße',
#     'addr:suburb': 'Marienthal',
#     'amenity': 'college',
#     'email': 'bsz-bau-zwickau@t-online.de',
#     'fax': '+49 375 5971341',
#     'name': 'Berufliches Schulzentrum für Bau- und Oberflächentechnik',
#     'phone': '+49 375 572174',
#     'website': 'http://www.bsz-bautechnik-zwickau.de',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 274129255,
#    'lat': 51.1692379,
#    'lon': 14.9728037,
#    'tags': {'amenity': 'college',
#     'name': 'Berufsbildungszentrum Baugewerbe Görlitz'}},
#   {'type': 'node',
#    'id': 274544274,
#    'lat': 48.7752913,
#    'lon': 9.1707585,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule Stuttgart',
#     'website': 'https://vhs-stuttgart.de/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 274638058,
#    'lat': 48.6795095,
#    'lon': 10.1500989,
#    'tags': {'addr:city': 'Heidenheim an der Brenz',
#     'addr:housenumber': '10',
#     'addr:postcode': '89518',
#     'addr:street': 'Wilhelmstraße',
#     'amenity': 'college',
#     'name': 'Duale Hochschule Heidenheim',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 278208067,
#    'lat': 50.6200521,
#    'lon': 6.9214298,
#    'tags': {'amenity': 'college', 'name': 'Garten und Landschaftbau'}},
#   {'type': 'node',
#    'id': 281896883,
#    'lat': 50.8950939,
#    'lon': 12.0770134,
#    'tags': {'amenity': 'college',
#     'name': 'VWA Gera',
#     'operator': 'VWA',
#     'operator:type': 'ngo',
#     'website': 'http://vwa-gera.de'}},
#   {'type': 'node',
#    'id': 292050006,
#    'lat': 51.0214361,
#    'lon': 7.6824521,
#    'tags': {'addr:city': 'Bergneustadt',
#     'addr:country': 'DE',
#     'addr:housenumber': '2',
#     'addr:postcode': '51702',
#     'addr:street': 'Eichendorffstraße',
#     'alt_name': 'Forum Wiedenest',
#     'amenity': 'college',
#     'contact:phone': '+49 2261 406-126',
#     'contact:website': 'http://www.wiedenest.de',
#     'name': 'Biblisch-Theologische Akadmie Wiedenest',
#     'operator': 'Forum Wiedenest e.V.',
#     'wheelchair': 'limited',
#     'wikidata': 'Q28739303'}},
#   {'type': 'node',
#    'id': 292126394,
#    'lat': 51.1848227,
#    'lon': 6.9390091,
#    'tags': {'addr:housenumber': '280',
#     'addr:street': 'Hochdahler Straße',
#     'amenity': 'college',
#     'created_by': 'JOSM',
#     'name': 'Institut für öffentliche Verwaltung',
#     'website': 'https://www.im.nrw.de/hom/13.htm',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 292199699,
#    'lat': 51.941972,
#    'lon': 7.1797794,
#    'tags': {'amenity': 'college',
#     'created_by': 'Potlatch 0.10b',
#     'name': 'Kolping Bildungsstätte',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 295529613,
#    'lat': 52.4659477,
#    'lon': 10.5428575,
#    'tags': {'amenity': 'college',
#     'name': 'Fachhochschule für Altenpflege / Oskar Kämmer Schule'}},
#   {'type': 'node',
#    'id': 299395546,
#    'lat': 50.3252934,
#    'lon': 11.9405309,
#    'tags': {'addr:city': 'Hof',
#     'addr:housenumber': '1',
#     'addr:postcode': '95028',
#     'addr:street': 'Alfons-Goppel-Platz',
#     'amenity': 'college',
#     'email': 'mail@hof-university.de',
#     'fax': '+49-9281-4094000',
#     'isced:level': '4',
#     'name': 'Hochschule Hof',
#     'name:de': 'Hochschule Hof',
#     'name:en': 'Hof University of Applied Sciences',
#     'phone': '+49-9281-4093000',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://www.hof-university.de/',
#     'wheelchair': 'yes',
#     'wikidata': 'Q1622109',
#     'wikipedia': 'de:Hochschule für Angewandte Wissenschaften Hof'}},
#   {'type': 'node',
#    'id': 305436638,
#    'lat': 47.6218087,
#    'lon': 7.662358,
#    'tags': {'amenity': 'college',
#     'name': 'Kaufmännische Schule Lörrach',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 305474647,
#    'lat': 49.3543813,
#    'lon': 9.1477682,
#    'tags': {'amenity': 'college', 'name': 'Volkshochschule Mosbach'}},
#   {'type': 'node',
#    'id': 306546457,
#    'lat': 51.512836,
#    'lon': 7.0915229,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 307181210,
#    'lat': 50.9565549,
#    'lon': 6.9556712,
#    'tags': {'addr:city': 'Köln',
#     'addr:country': 'DE',
#     'addr:housenumber': '99',
#     'addr:postcode': '50670',
#     'addr:street': 'Neusser Straße',
#     'amenity': 'college',
#     'asb': '72',
#     'name': 'praxisHochschule Köln',
#     'note:de': 'http://wiki.openstreetmap.org/index.php/DE:DSL_Hauptverteiler',
#     'onkz': '221',
#     'operator': 'praxisHochschule Köln',
#     'phone': '+49 221 5000 330 30',
#     'source': 'praxisHochschule Köln',
#     'website': 'http://www.praxishochschule.de',
#     'wikidata': 'Q16855778'}},
#   {'type': 'node',
#    'id': 308040605,
#    'lat': 51.4551245,
#    'lon': 7.0139037,
#    'tags': {'addr:city': 'Essen',
#     'addr:country': 'DE',
#     'addr:housenumber': '1',
#     'addr:postcode': '45127',
#     'addr:street': 'Burgplatz',
#     'amenity': 'college',
#     'entrance': 'main',
#     'name': 'Volkshochschule',
#     'toilets:wheelchair': 'yes',
#     'website': 'http://www.vhs-essen.de',
#     'wheelchair': 'yes',
#     'wikidata': 'Q2532006',
#     'wikipedia': 'de:Volkshochschule Essen'}},
#   {'type': 'node',
#    'id': 310154260,
#    'lat': 51.1952876,
#    'lon': 6.6973096,
#    'tags': {'amenity': 'college', 'name': 'VHS'}},
#   {'type': 'node',
#    'id': 312080129,
#    'lat': 52.2554253,
#    'lon': 12.9293312,
#    'tags': {'addr:city': 'Beelitz',
#     'addr:country': 'DE',
#     'addr:housenumber': '16 B',
#     'addr:postcode': '14547',
#     'addr:street': 'Straße nach Fichtenwalde',
#     'addr:suburb': 'Beelitz-Heilstätten',
#     'amenity': 'college',
#     'email': 'beelitz@akademie-beelitz.de',
#     'fax': '+49 33204 21455',
#     'historic': 'yes',
#     'name': 'Akademie für Sozial- und Gesundheitsberufe',
#     'old_name': 'Landesfachklinik für Lungenheilkunde',
#     'operator': 'Recura Kliniken GmbH',
#     'phone': '+49 33204 21450',
#     'website': 'www.akademie-beelitz.de',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 313476032,
#    'lat': 49.7822721,
#    'lon': 9.9062935,
#    'tags': {'amenity': 'college',
#     'name': 'Friedrich-Ebert-Stiftung',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 325675488,
#    'lat': 47.9126929,
#    'lon': 11.4203007,
#    'tags': {'amenity': 'college', 'name': 'Jugendhaus'}},
#   {'type': 'node',
#    'id': 333705588,
#    'lat': 53.0010191,
#    'lon': 13.153532,
#    'tags': {'amenity': 'college',
#     'name': 'Strittmatter-Gymnasium',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 337600969,
#    'lat': 51.8391933,
#    'lon': 6.8678502,
#    'tags': {'addr:city': 'Borken',
#     'addr:country': 'DE',
#     'addr:housenumber': '10',
#     'addr:postcode': '46325',
#     'addr:street': 'Josefstraße',
#     'amenity': 'college',
#     'name': 'Berufskolleg',
#     'wheelchair': 'no',
#     'wikidata': 'Q828976',
#     'wikipedia': 'de:Berufskolleg Borken'}},
#   {'type': 'node',
#    'id': 343479322,
#    'lat': 50.3250284,
#    'lon': 11.9369852,
#    'tags': {'addr:city': 'Hof',
#     'addr:housenumber': '51',
#     'addr:postcode': '95028',
#     'addr:street': 'Wirthstraße',
#     'alt_name': 'FHVR-AIV',
#     'amenity': 'college',
#     'name': 'Hochschule für den öffentlichen Dienst in Bayern - Fachbereich Allgemeine Innere Verwaltung',
#     'phone': '+49 9281 409-100',
#     'website': 'https://www.aiv.hfoed.de/de/startseite.html',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 344376786,
#    'lat': 48.9038358,
#    'lon': 8.5031882,
#    'tags': {'amenity': 'college', 'name': 'Langensteinbacher Höhe'}},
#   {'type': 'node',
#    'id': 348413197,
#    'lat': 51.519947,
#    'lon': 7.460431,
#    'tags': {'addr:city': 'Dortmund',
#     'addr:country': 'DE',
#     'addr:housename': 'Auslandsgesellschaft Deutschland e. V.',
#     'addr:housenumber': '48',
#     'addr:postcode': '44147',
#     'addr:street': 'Steinstraße',
#     'amenity': 'college',
#     'contact:website': 'http://www.auslandsgesellschaft.de/',
#     'name': 'Auslandsgesellschaft NRW e. V.'}},
#   {'type': 'node',
#    'id': 359590537,
#    'lat': 53.6319479,
#    'lon': 11.4168818,
#    'tags': {'addr:housenumber': '13',
#     'addr:street': 'Puschkinstraße',
#     'amenity': 'college',
#     'name': 'Volkshochschule EhmWelk',
#     'website': 'www.vhs-schwerin.de',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 360279222,
#    'lat': 53.5548816,
#    'lon': 10.0710984,
#    'tags': {'amenity': 'college',
#     'contact:phone': '+49 40 65591-181',
#     'contact:website': 'http://www.ev-hochschule-hh.de/',
#     'denomination': 'protestant',
#     'name': 'Evangelische Hochschule für Soziale Arbeit und Diakonie',
#     'operator': 'Das Rauhe Haus',
#     'religion': 'christian',
#     'school:de': 'Berufsschule'}},
#   {'type': 'node',
#    'id': 362758006,
#    'lat': 50.9845314,
#    'lon': 12.4241965,
#    'tags': {'addr:city': 'Altenburg',
#     'addr:housenumber': '6',
#     'addr:postcode': '04600',
#     'addr:street': 'Hospitalplatz',
#     'amenity': 'college',
#     'email': 'vhs-altenburg@altenburgerland.de',
#     'internet_access': 'wlan',
#     'name': 'Volkshochschule Altenburger Land, Geschäftsstelle Altenburg',
#     'operator': 'Landkreis Altenburger Land',
#     'website': 'https://www.vhs-altenburgerland.de'}},
#   {'type': 'node',
#    'id': 370562341,
#    'lat': 48.8212733,
#    'lon': 9.2021322,
#    'tags': {'addr:city': 'Stuttgart',
#     'addr:housenumber': '7',
#     'addr:postcode': '70376',
#     'addr:street': 'Kölner Straße',
#     'amenity': 'college',
#     'email': 'stuttgart@akademie-bw.de',
#     'fax': '+49 7 11 95 48 04 99',
#     'image': 'https://www.akademie-bw.de/_Resources/Static/Packages/AFK.Responsive/Images/logo.png',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'customers',
#     'name': 'Akademie für Kommunikation',
#     'operator': 'Verwaltungsgesellschaft der Akademien zur Förderung der Kommunikation mbH',
#     'operator:type': 'private',
#     'phone': '+49 7 11  95 48 04 0',
#     'website': 'https://www.akademie-bw.de'}},
#   {'type': 'node',
#    'id': 373151046,
#    'lat': 54.7833234,
#    'lon': 9.4351567,
#    'tags': {'amenity': 'college', 'name': 'VHS-Zentrum', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 378364796,
#    'lat': 50.6239315,
#    'lon': 12.290229,
#    'tags': {'amenity': 'college',
#     'name': 'Westsächsische Hochschule (FH)',
#     'operator': 'Westsächsische Hochschule Zwickau',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 383594325,
#    'lat': 53.5546873,
#    'lon': 9.9497335,
#    'tags': {'amenity': 'college',
#     'contact:email': 'info@artrium-hamburg.de',
#     'contact:phone': '+49 40 28055131',
#     'contact:website': 'https://www.schauspielschule-artrium-hamburg.de',
#     'name': 'Artrium - Schauspielschule Hamburg',
#     'operator': 'Artrium - Schauspielschule Hamburg'}},
#   {'type': 'node',
#    'id': 389081205,
#    'lat': 52.4618586,
#    'lon': 13.5233889,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '7',
#     'addr:postcode': '12459',
#     'addr:street': 'Plönzeile',
#     'addr:suburb': 'Oberschöneweide',
#     'amenity': 'college',
#     'name': 'Schule'}},
#   {'type': 'node',
#    'id': 401770611,
#    'lat': 47.7605626,
#    'lon': 11.7336237,
#    'tags': {'amenity': 'college',
#     'email': 'vhs-gmund@t-online.de',
#     'name': 'Volkshochschule',
#     'note': 'Ehem. Rathaus Dürnbach',
#     'phone': '+49-8022-7254',
#     'toilets:wheelchair': 'no',
#     'website': 'http://www.vhs-gmund.de',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 415442623,
#    'lat': 49.1135993,
#    'lon': 9.7353299,
#    'tags': {'amenity': 'college',
#     'name': 'Goethe-Institut',
#     'name:lt': 'Gėtės institutas',
#     'name:pl': 'Instytut Goethego',
#     'name:uk': 'Ґете-Iнститут',
#     'website': 'http://www.goethe.de/ins/de/ort/swh/',
#     'wheelchair': 'no',
#     'wikidata': 'Q157033',
#     'wikipedia': 'de:Goethe-Institut'}},
#   {'type': 'node',
#    'id': 417798073,
#    'lat': 49.1343222,
#    'lon': 10.0722781,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 429155189,
#    'lat': 51.5390446,
#    'lon': 9.9332318,
#    'tags': {'addr:city': 'Göttingen',
#     'addr:country': 'DE',
#     'addr:housenumber': '3',
#     'addr:postcode': '37073',
#     'addr:street': 'Weender Landstraße',
#     'amenity': 'college',
#     'contact:phone': '+49 551 54700-0',
#     'contact:website': 'https://www.pfh.de/',
#     'description': 'Private University of Applied Science',
#     'level': '1;2',
#     'name': 'PFH Private Hochschule Göttingen',
#     'start_date': '1995'}},
#   {'type': 'node',
#    'id': 429251594,
#    'lat': 52.3017709,
#    'lon': 13.6259192,
#    'tags': {'addr:city': 'Königs Wusterhausen',
#     'addr:country': 'DE',
#     'addr:housenumber': '1 b',
#     'addr:postcode': '15711',
#     'addr:street': 'Schulweg',
#     'amenity': 'college',
#     'name': 'Volkshochschule Dahme-Spreewald',
#     'operator': 'Landkreis Dahme-Spreewald'}},
#   {'type': 'node',
#    'id': 431185321,
#    'lat': 50.1839792,
#    'lon': 8.5197276,
#    'tags': {'amenity': 'college',
#     'name': 'Religionspädagogisches Zentrum Kronberg RPZ',
#     'operator': 'evangelische Kirche in Hessen und Nassau'}},
#   {'type': 'node',
#    'id': 432527599,
#    'lat': 52.2990957,
#    'lon': 13.6257815,
#    'tags': {'amenity': 'college', 'name': 'Kreismusikschule Dahme-Spreewald'}},
#   {'type': 'node',
#    'id': 445427335,
#    'lat': 50.1205309,
#    'lon': 8.6572176,
#    'tags': {'amenity': 'college',
#     'name': 'Römisch-Germanische Kommission des DAI'}},
#   {'type': 'node',
#    'id': 494613499,
#    'lat': 51.2515877,
#    'lon': 6.95154,
#    'tags': {'addr:city': 'Mettmann',
#     'addr:housenumber': '6',
#     'addr:postcode': '40822',
#     'addr:street': 'Marie-Curie-Straße',
#     'amenity': 'college',
#     'name': 'Fachhochschule der Wirtschaft FHDW (Campus Mettmann)',
#     'wheelchair:description': 'Weitere Informationen bzgl. der Barrierefreiheit finden Sie unter folgenden Link: http://www.kombabb-internetportal-nrw.de/plugin.php?menuid=6&template=mv/templates/mv_show_front.html&mv_id=1&extern_meta=x&mv_content_id=88'}},
#   {'type': 'node',
#    'id': 502567533,
#    'lat': 52.4797318,
#    'lon': 13.4267486,
#    'tags': {'amenity': 'college', 'name': 'Otto-Suhr-Volkshochschule'}},
#   {'type': 'node',
#    'id': 503559837,
#    'lat': 52.3727322,
#    'lon': 9.7311288,
#    'tags': {'addr:city': 'Hannover',
#     'addr:country': 'DE',
#     'addr:housenumber': '14',
#     'addr:postcode': '30159',
#     'addr:street': 'Burgstraße',
#     'alt_name': 'Volkshochschule Hannover',
#     'alt_name_1': 'VHS Hannover',
#     'amenity': 'college',
#     'email': 'info.vhs@hannover-stadt.de',
#     'name': 'Ada-und-Theodor-Lessing-Volkshochschule',
#     'operator': 'Landeshauptstadt Hannover',
#     'phone': '+49 511 168-44783',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://www.vhs-hannover.de/',
#     'wheelchair': 'yes',
#     'wikidata': 'Q2532014',
#     'wikipedia': 'de:Ada-und-Theodor-Lessing-Volkshochschule'}},
#   {'type': 'node',
#    'id': 507420528,
#    'lat': 52.5172615,
#    'lon': 13.5200632,
#    'tags': {'amenity': 'college',
#     'name': 'TÜV Rheinland Akademie',
#     'website': 'https://www.tuv.com/de/tuev_rheinland_akademie_in_berlin_und_umgebung.html'}},
#   {'type': 'node',
#    'id': 535091832,
#    'lat': 51.5352877,
#    'lon': 9.9321521,
#    'tags': {'addr:city': 'Göttingen',
#     'addr:country': 'DE',
#     'addr:housename': 'AKAdemie Göttingen',
#     'addr:housenumber': '4',
#     'addr:postcode': '37073',
#     'addr:street': 'Am Leinekanal',
#     'amenity': 'college',
#     'contact:fax': '+49 551 7896863',
#     'contact:phone': '+49 551 7896862',
#     'contact:website': 'http://www.akage.de/',
#     'name': 'AKAdemie Göttingen',
#     'survey:date': '2015-12-27',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 535394278,
#    'lat': 51.3344747,
#    'lon': 6.5593048,
#    'tags': {'addr:city': 'Krefeld',
#     'addr:country': 'DE',
#     'addr:housenumber': '2',
#     'addr:postcode': '47798',
#     'addr:street': 'Von-der-Leyen-Platz',
#     'amenity': 'college',
#     'name': 'Volkshochschule Krefeld',
#     'website': 'https://www.krefeld.de/vhs',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 536749593,
#    'lat': 53.582423,
#    'lon': 10.0501367,
#    'tags': {'amenity': 'college',
#     'name': 'HFH Studienzentrum Hamburg',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 537161358,
#    'lat': 52.5051161,
#    'lon': 13.4480863,
#    'tags': {'amenity': 'college', 'name': 'Die Managementschule Berlin'}},
#   {'type': 'node',
#    'id': 542892914,
#    'lat': 52.5135064,
#    'lon': 13.3908638,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '55',
#     'addr:postcode': '10117',
#     'addr:street': 'Charlottenstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'college',
#     'name': 'Hochschule für Musik Hanns Eisler Berlin',
#     'name:de': 'Hochschule für Musik Hanns Eisler Berlin',
#     'name:en': 'Academy of Music Hanns Eisler Berlin',
#     'phone': '+4930688305700',
#     'website': 'https://www.hfm-berlin.de/',
#     'wheelchair': 'no',
#     'wikidata': 'Q569460'}},
#   {'type': 'node',
#    'id': 567958126,
#    'lat': 52.15378,
#    'lon': 14.6284518,
#    'tags': {'amenity': 'college', 'name': 'Volkshochschule'}},
#   {'type': 'node',
#    'id': 568338178,
#    'lat': 53.607177,
#    'lon': 10.1198236,
#    'tags': {'addr:city': 'Hamburg',
#     'addr:country': 'DE',
#     'addr:housenumber': '183',
#     'addr:postcode': '22159',
#     'addr:street': 'Berner Heerweg',
#     'amenity': 'college',
#     'description': 'Erwachsenenbildung',
#     'name': 'Hamburger Volkshochschule Region Ost',
#     'operator': 'Hamburger Volkshochschule Landesbetrieb der Freien und Hansestadt Hamburg',
#     'operator:type': 'public',
#     'vocational': 'yes',
#     'website': 'https://www.vhs-hamburg.de/vhs-standorte/vhs-zentrum-ost-930'}},
#   {'type': 'node',
#    'id': 571122864,
#    'lat': 47.9942274,
#    'lon': 7.8336793,
#    'tags': {'addr:city': 'Freiburg im Breisgau',
#     'addr:housenumber': '6a',
#     'addr:postcode': '79106',
#     'addr:street': 'Ferdinand-Weiß-Straße',
#     'amenity': 'college',
#     'contact:website': 'https://freiburger-schauspielschule.de',
#     'door': 'yes',
#     'email': 'fss.kiee@t-online.de',
#     'entrance': 'yes',
#     'level': '-1',
#     'name': 'Freiburger Schauspielschule',
#     'note:de': 'staatlichanerkannte Berufsfachschule',
#     'opening_hours:office': '09:30-12:30; Sa,Su,PH off',
#     'phone': '+49 761 381191; +49 761 287461',
#     'website': 'https://freiburger-schauspielschule.de',
#     'wikidata': 'Q1453881',
#     'wikipedia': 'de:Freiburger Schauspielschule im E-Werk'}},
#   {'type': 'node',
#    'id': 571374849,
#    'lat': 49.5956664,
#    'lon': 11.0076979,
#    'tags': {'addr:city': 'Erlangen',
#     'addr:country': 'DE',
#     'addr:housenumber': '19',
#     'addr:postcode': '91054',
#     'addr:street': 'Friedrichstraße',
#     'alt_name': 'Volkshochschule der Stadt Erlangen',
#     'amenity': 'college',
#     'name': 'Volkshochschule',
#     'phone': '+49 9131 86 2668',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 573366985,
#    'lat': 50.1202144,
#    'lon': 8.6762253,
#    'tags': {'amenity': 'college',
#     'name': 'Hochschule für Musik und Darstellende Kunst',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 582654515,
#    'lat': 49.4786407,
#    'lon': 8.4654995,
#    'tags': {'addr:city': 'Mannheim',
#     'addr:country': 'DE',
#     'addr:housenumber': '2',
#     'addr:postcode': '68163',
#     'addr:street': 'Rennershofstraße',
#     'amenity': 'college',
#     'name': 'Helene-Lange-Schule - Fröbel-Seminar',
#     'website': 'http://www.helene-lange-schule-mannheim.de'}},
#   {'type': 'node',
#    'id': 596255976,
#    'lat': 54.233273,
#    'lon': 10.2750373,
#    'tags': {'addr:city': 'Preetz',
#     'addr:country': 'DE',
#     'addr:housenumber': '10',
#     'addr:postcode': '24211',
#     'addr:street': 'Hinter dem Kirchhof',
#     'amenity': 'college',
#     'name': 'AWO Bildungszentrum Preetz - Fachschule für Altenpflege',
#     'website': 'http://ausbildung-altenpflege.org/bz-preetz/'}},
#   {'type': 'node',
#    'id': 619257310,
#    'lat': 52.5390892,
#    'lon': 11.9699179,
#    'tags': {'amenity': 'college',
#     'description:de': 'Privat-Gymnasium',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 626795381,
#    'lat': 48.2448501,
#    'lon': 10.3629207,
#    'tags': {'amenity': 'college',
#     'name': 'Joseph-Bernhart-Fachakademie für Sozialpädagogik',
#     'website': 'http://www.fachakademie-kru.de/'}},
#   {'type': 'node',
#    'id': 650736130,
#    'lat': 48.7533933,
#    'lon': 11.4437255,
#    'tags': {'amenity': 'college',
#     'name': 'Mittelschule an der Stollstraße',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 652383149,
#    'lat': 54.3615208,
#    'lon': 10.1297301,
#    'tags': {'addr:city': 'Kiel',
#     'addr:country': 'DE',
#     'addr:housenumber': '1-3',
#     'addr:postcode': '24106',
#     'addr:street': 'Flintkampsredder',
#     'amenity': 'college',
#     'name': 'Med-Ecole, Lehrinstitut für Notfallmedizin',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 654562624,
#    'lat': 49.3282256,
#    'lon': 8.4119894,
#    'tags': {'addr:city': 'Speyer',
#     'addr:country': 'DE',
#     'addr:housenumber': '67a',
#     'addr:postcode': '67346',
#     'addr:street': 'Im Erlich',
#     'amenity': 'college',
#     'name': 'Stadt- und Kreisbildstelle',
#     'website': 'http://mz-speyer.bildung-rp.de/'}},
#   {'type': 'node',
#    'id': 654562628,
#    'lat': 49.3171551,
#    'lon': 8.4207741,
#    'tags': {'amenity': 'college',
#     'name': 'Staatliches Studienseminar für das Lehramt an Gymnasien',
#     'website': 'http://studienseminar.rlp.de/gym/speyer.html',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 654562630,
#    'lat': 49.3176377,
#    'lon': 8.4203072,
#    'tags': {'amenity': 'college',
#     'name': 'Staatliches Studienseminar für das Lehramt an Berufsbildenden Schulen',
#     'note': 'website http://www.sembbsrp.de/index.php?id=7 can not be opened (Statuscode 403)',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 654562634,
#    'lat': 49.3107692,
#    'lon': 8.4340758,
#    'tags': {'amenity': 'college',
#     'contact:website': 'http://www.diakonissen.de/aus-und-fortbildung/ausbildungszentrum-fuergesundheit-und-soziales.html',
#     'name': 'Ausbildungszentrum Gesundheit und Soziales der Diakonissen Speyer-Mannheim',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 654562638,
#    'lat': 49.3212477,
#    'lon': 8.4305389,
#    'tags': {'addr:city': 'Speyer',
#     'addr:country': 'DE',
#     'addr:housenumber': '54',
#     'addr:postcode': '67346',
#     'addr:street': 'Bahnhofstraße',
#     'alt_name': 'Volkshochschule Speyer, Villa Ecarius',
#     'amenity': 'college',
#     'fax': '+49-6232-14-1379',
#     'name': 'Volkshochschule Speyer',
#     'phone': '+49-6232-14-1360',
#     'website': 'https://www.vhs-speyer.de/',
#     'wheelchair': 'yes',
#     'wheelchair:description': '56 Stufen, schwellelose Rampe vorhanden, Behindertentoilette vorhanden, Behindertenparkplatz'}},
#   {'type': 'node',
#    'id': 654562640,
#    'lat': 49.3213982,
#    'lon': 8.4306223,
#    'tags': {'addr:city': 'Speyer',
#     'addr:country': 'DE',
#     'addr:housenumber': '54',
#     'addr:postcode': '67346',
#     'addr:street': 'Bahnhofstraße',
#     'amenity': 'college',
#     'name': 'Musikschule der Stadt Speyer',
#     'phone': '+49 6232/106106',
#     'website': 'http://tonebird.org/',
#     'wheelchair': 'yes',
#     'wheelchair:description': '56 Stufen, schwellelose Rampe vorhanden, Behindertentoilette vorhanden, Behindertenparkplatz'}},
#   {'type': 'node',
#    'id': 654562648,
#    'lat': 49.3161747,
#    'lon': 8.441039,
#    'tags': {'amenity': 'college',
#     'fixme': 'position',
#     'name': 'Evangelische Akademie der Pfalz',
#     'website': 'https://www.eapfalz.de/'}},
#   {'type': 'node',
#    'id': 659435861,
#    'lat': 51.7315923,
#    'lon': 7.5335072,
#    'tags': {'amenity': 'college',
#     'name': 'Fachhochschule für Finanzen',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Weitere Informationen bzgl. der Barrierefreiheit finden Sie unter folgenden Link: http://www.kombabb-internetportal-nrw.de/plugin.php?menuid=6&template=mv/templates/mv_show_front.html&mv_id=1&extern_meta=x&mv_content_id=17'}},
#   {'type': 'node',
#    'id': 660181611,
#    'lat': 47.9921026,
#    'lon': 7.8348994,
#    'tags': {'addr:city': 'Freiburg im Breisgau',
#     'addr:housenumber': '15',
#     'addr:postcode': '79115',
#     'addr:street': 'Haslacher Straße',
#     'amenity': 'college',
#     'contact:website': 'https://www.macromedia-fachhochschule.de/standorte/campus-freiburg.html',
#     'entrance': 'main',
#     'name': 'Hochschule Macromedia Freiburg',
#     'noexit': 'yes',
#     'wikidata': 'Q1622192',
#     'wikipedia': 'de:Hochschule für Kunst, Design und Populäre Musik Freiburg'}},
#   {'type': 'node',
#    'id': 666210218,
#    'lat': 51.2173578,
#    'lon': 6.8036996,
#    'tags': {'addr:city': 'Düsseldorf',
#     'addr:country': 'DE',
#     'addr:housenumber': '4',
#     'addr:postcode': '40227',
#     'addr:street': 'Werdener Straße',
#     'amenity': 'college',
#     'fax': '+49 211 179393-17',
#     'name': 'Mediadesign Hochschule',
#     'phone': '+49 211 1793930',
#     'short_name': 'MD.H',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://www.mediadesign.de/',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Weitere Informationen bzgl. der Barrierefreiheit finden Sie unter folgenden Link: http://www.kombabb-internetportal-nrw.de/plugin.php?menuid=6&template=mv/templates/mv_show_front.html&mv_id=1&extern_meta=x&mv_content_id=97',
#     'wikidata': 'Q1916178',
#     'wikipedia': 'de:Mediadesign Hochschule'}},
#   {'type': 'node',
#    'id': 666210219,
#    'lat': 51.2187544,
#    'lon': 6.7860526,
#    'tags': {'addr:city': 'Düsseldorf',
#     'addr:country': 'DE',
#     'addr:housenumber': '61',
#     'addr:postcode': '40210',
#     'addr:street': 'Graf-Adolf-Straße',
#     'amenity': 'college',
#     'fax': '+49 211 3858136',
#     'name': 'Düsseldorfer Akademie für Marketing-Kommunikation',
#     'note': 'Verwaltung; Unterricht in der FH Düsseldorf',
#     'phone': '+49 211 373900',
#     'website': 'https://www.damk.de/',
#     'wheelchair': 'no',
#     'wikipedia': 'de:Düsseldorfer Akademie für Marketing-Kommunikation'}},
#   {'type': 'node',
#    'id': 675649596,
#    'lat': 49.0390998,
#    'lon': 9.1177803,
#    'tags': {'amenity': 'college',
#     'name': 'Hohenstein Institute',
#     'website': 'https://www.hohenstein.de/',
#     'wikidata': 'Q1623815'}},
#   {'type': 'node',
#    'id': 678489862,
#    'lat': 49.4130105,
#    'lon': 8.6554404,
#    'tags': {'amenity': 'college',
#     'name': 'SRH Fachschulen',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 682148858,
#    'lat': 49.8031459,
#    'lon': 9.9519307,
#    'tags': {'amenity': 'college',
#     'name': 'Übungsfirma Molkereiprodukte',
#     'operator': 'Frankenland GmbH'}},
#   {'type': 'node',
#    'id': 682148868,
#    'lat': 49.8032154,
#    'lon': 9.9519505,
#    'tags': {'amenity': 'college',
#     'name': 'Übungsfirma Mineralölverkauf',
#     'operator': 'DEA'}},
#   {'type': 'node',
#    'id': 684434171,
#    'lat': 51.8481629,
#    'lon': 6.8591665,
#    'tags': {'amenity': 'college',
#     'name': 'Fachschule für Landwirtschaft Borken'}},
#   {'type': 'node',
#    'id': 694441612,
#    'lat': 49.0556794,
#    'lon': 9.2463386,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule Unterland',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 705763586,
#    'lat': 51.5188891,
#    'lon': 7.4729555,
#    'tags': {'amenity': 'college',
#     'email': 'buero@rbb-dortmund.de',
#     'fax': '+49 231 50251 20',
#     'name': 'Robert-Bosch-Berufskolleg',
#     'phone': '+49 231 50231 47',
#     'website': 'http://rbb-dortmund.de',
#     'wikidata': 'Q2156201',
#     'wikipedia': 'de:Robert-Bosch-Berufskolleg (Dortmund)'}},
#   {'type': 'node',
#    'id': 705763633,
#    'lat': 51.5193444,
#    'lon': 7.4736882,
#    'tags': {'addr:city': 'Dortmund',
#     'addr:country': 'DE',
#     'addr:housenumber': '4',
#     'addr:postcode': '44135',
#     'addr:street': 'Gronaustraße',
#     'amenity': 'college',
#     'email': 'leopold-hoesch-berufskolleg@stadt-do.de',
#     'fax': '+49 231 526731',
#     'fixme': 'Zuordnung Gebäude im Kolleg-Komplex',
#     'name': 'Leopold-Hoesch-Berufskolleg',
#     'phone': '+49 231 5023151',
#     'website': 'https://www.lhb-do.de/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 705767181,
#    'lat': 51.5181962,
#    'lon': 7.472015,
#    'tags': {'addr:city': 'Dortmund',
#     'addr:housenumber': '25-27a',
#     'addr:postcode': '44135',
#     'addr:street': 'Brügmannstraße',
#     'amenity': 'college',
#     'email': 'verwaltung@fhbk.de',
#     'fax': '+49 231 577252',
#     'name': 'Fritz-Henßler-Berufskolleg',
#     'opening_hours': 'Mo-Tu 7:30-12:00, 13:00-14:30, Fr 7:30-12:00',
#     'phone': '+49 231 5023156',
#     'website': 'https://www.fhbk.de/',
#     'wikidata': 'Q21334538',
#     'wikipedia': 'de:Fritz-Henßler-Berufskolleg'}},
#   {'type': 'node',
#    'id': 705773505,
#    'lat': 51.5181775,
#    'lon': 7.4736997,
#    'tags': {'addr:city': 'Dortmund',
#     'addr:country': 'DE',
#     'addr:housenumber': '1-3',
#     'addr:postcode': '44135',
#     'addr:street': 'Geschwister-Scholl-Straße',
#     'amenity': 'college',
#     'email': '180051@schule.nrw.de',
#     'fax': '+49 231 577261',
#     'fixme': 'Zuordnung Gebäude im Kolleg-Komplex',
#     'name': 'Konrad-Klepping-Berufskolleg',
#     'phone': '+49 231 5023166',
#     'website': 'https://www.konrad-klepping-berufskolleg.de/',
#     'wikidata': 'Q1250029',
#     'wikipedia': 'de:Konrad-Klepping-Berufskolleg'}},
#   {'type': 'node',
#    'id': 705777025,
#    'lat': 51.5176296,
#    'lon': 7.4714128,
#    'tags': {'addr:city': 'Dortmund',
#     'addr:housenumber': '21',
#     'addr:postcode': '44135',
#     'addr:street': 'Brügmannstraße',
#     'amenity': 'college',
#     'email': 'karl-schiller-berufskolleg@stadtdo.de',
#     'fax': '+49 231 577250',
#     'name': 'Karl-Schiller-Berufskolleg',
#     'phone': '+49 231 5023172',
#     'website': 'http://www.ksbk-do.de/'}},
#   {'type': 'node',
#    'id': 710442256,
#    'lat': 52.6178266,
#    'lon': 10.0471058,
#    'tags': {'addr:city': 'Celle',
#     'addr:country': 'DE',
#     'amenity': 'college',
#     'name': 'Axel-Bruns-Schule - Berufsbildende Schule II'}},
#   {'type': 'node',
#    'id': 741103895,
#    'lat': 52.3389876,
#    'lon': 8.9931364,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule „Alte Molkerei“ Frille'}},
#   {'type': 'node',
#    'id': 823296001,
#    'lat': 48.7925815,
#    'lon': 9.7760449,
#    'tags': {'addr:city': 'Schwäbisch Gmünd',
#     'addr:country': 'DE',
#     'addr:housenumber': '135/2',
#     'addr:postcode': '73529',
#     'addr:street': 'Lorcher Straße',
#     'amenity': 'college',
#     'name': 'Kombrecht-Engel-Schule',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 829868008,
#    'lat': 47.5569358,
#    'lon': 9.6976279,
#    'tags': {'amenity': 'college',
#     'internet_access': 'wired',
#     'name': 'Berufliche Oberschule Lindau',
#     'operator': 'Freistaat Bayern'}},
#   {'type': 'node',
#    'id': 829903755,
#    'lat': 47.5459565,
#    'lon': 9.6772208,
#    'tags': {'amenity': 'college', 'name': 'Volkshochschule Lindau'}},
#   {'type': 'node',
#    'id': 846112329,
#    'lat': 51.3177066,
#    'lon': 9.4293372,
#    'tags': {'amenity': 'college',
#     'name': 'HS Bund - Fachbereich Landwirtschaftliche Sozialversicherung',
#     'operator': 'Hochschule des Bundes für öffentliche Verwaltung',
#     'website': 'http://www.hsbund.de'}},
#   {'type': 'node',
#    'id': 864113558,
#    'lat': 53.5794889,
#    'lon': 10.0456451,
#    'tags': {'addr:city': 'Hamburg',
#     'addr:country': 'DE',
#     'addr:housenumber': '55',
#     'addr:postcode': '22081',
#     'addr:street': 'Dehnhaide',
#     'amenity': 'college',
#     'name': 'Akademie deutsche POP',
#     'website': 'www.deutsche-pop.de'}},
#   {'type': 'node',
#    'id': 892568035,
#    'lat': 52.5128055,
#    'lon': 13.3893204,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '180',
#     'addr:postcode': '10117',
#     'addr:street': 'Friedrichstraße',
#     'addr:suburb': 'Mitte',
#     'amenity': 'college',
#     'name': 'Hertie School of Governance',
#     'name:en': 'Hertie school of Governance',
#     'phone': '+49302592190',
#     'website': 'https://www.hertie-school.org/de/home/',
#     'wheelchair': 'yes',
#     'wikidata': 'Q317156'}},
#   {'type': 'node',
#    'id': 893271170,
#    'lat': 53.5764903,
#    'lon': 7.7789621,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule und Musikschule',
#     'website': 'https://www.vhs-frieslandwittmund.de/'}},
#   {'type': 'node',
#    'id': 900934277,
#    'lat': 51.5199039,
#    'lon': 7.460558,
#    'tags': {'amenity': 'college',
#     'contact:website': 'http://auslandsgesellschaft-deutschland.de/',
#     'name': 'Auslandsgesellschaft Intercultural Academy gGmbH',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 904958864,
#    'lat': 52.5314489,
#    'lon': 13.4252721,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '14',
#     'addr:postcode': '10405',
#     'addr:street': 'Immanuelkirchstraße',
#     'addr:suburb': 'Prenzlauer Berg',
#     'amenity': 'college',
#     'contact:website': 'http://www.cimdata.de',
#     'name': 'cimdata'}},
#   {'type': 'node',
#    'id': 920075341,
#    'lat': 53.7916945,
#    'lon': 9.9804873,
#    'tags': {'addr:city': 'Henstedt-Ulzburg',
#     'addr:country': 'DE',
#     'addr:housenumber': '24',
#     'addr:postcode': '24558',
#     'addr:street': 'Hamburger Straße',
#     'amenity': 'college',
#     'name': 'Volkshochschule Henstedt-Ulzburg',
#     'short_name': 'VHS',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 933541147,
#    'lat': 48.0968564,
#    'lon': 11.5321306,
#    'tags': {'addr:city': 'München',
#     'addr:country': 'DE',
#     'addr:housenumber': '28',
#     'addr:postcode': '81379',
#     'addr:street': 'Baierbrunner Straße',
#     'amenity': 'college',
#     'name': 'Sprachen & Dolmetscher Institut München e. V.',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 935345052,
#    'lat': 49.7999926,
#    'lon': 10.2095772,
#    'tags': {'amenity': 'college',
#     'name': 'Integratives Bildungszentrum (IBIZ)'}},
#   {'type': 'node',
#    'id': 937883304,
#    'lat': 51.4568791,
#    'lon': 7.2258187,
#    'tags': {'amenity': 'college',
#     'name': 'Fachhochschule des Bundes für öffentliche Verwaltung',
#     'operator': 'Deutsche Rentenversicherung Knappschaft-Bahn-See',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 943273912,
#    'lat': 51.7552263,
#    'lon': 11.0462806,
#    'tags': {'amenity': 'college',
#     'name': 'Aus- und Fortbildungsinstitut des Landes Sachsen-Anhalt',
#     'operator': 'Bundesland Sachsen-Anhalt',
#     'operator:type': 'government'}},
#   {'type': 'node',
#    'id': 944540661,
#    'lat': 51.4524384,
#    'lon': 7.2086403,
#    'tags': {'amenity': 'college',
#     'name': 'Zentrum Audiovisuelle Medientechnik der Technischen Akademie Wuppertal e. V.'}},
#   {'type': 'node',
#    'id': 956093147,
#    'lat': 49.413994,
#    'lon': 8.653702,
#    'tags': {'amenity': 'college',
#     'name': 'SRH Fachschule für Logopädie',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 990262315,
#    'lat': 49.0097594,
#    'lon': 8.388582,
#    'tags': {'addr:city': 'Karlsruhe',
#     'addr:country': 'DE',
#     'addr:housenumber': '81',
#     'addr:postcode': '76133',
#     'addr:street': 'Amalienstraße',
#     'amenity': 'college',
#     'level': '5',
#     'name': 'Paracelsus Heilpraktikerschule',
#     'website': 'http://www.paracelsus.de/map/ort75/ort75.asp',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 996531161,
#    'lat': 51.3600039,
#    'lon': 8.4836238,
#    'tags': {'amenity': 'college',
#     'name': 'Berufskolleg Olsberg',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1006920844,
#    'lat': 50.7776244,
#    'lon': 6.0820799,
#    'tags': {'addr:city': 'Aachen',
#     'addr:floor': '3',
#     'addr:housenumber': '2a',
#     'addr:postcode': '52062',
#     'addr:street': 'Augustinerbach',
#     'amenity': 'college',
#     'email': 'fs@fsmpi.rwth-aachen.de',
#     'name': 'RWTH | Fachschaft Mathematik/Physik/Informatik',
#     'opening_hours': 'Mo-Fr 12:00-14:00',
#     'operator': 'Fachschaft Mathematik/Physik/Informatik',
#     'phone': '+49 241 8094506',
#     'short_name': 'FSMPI',
#     'website': 'https://www.fsmpi.rwth-aachen.de/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1024995677,
#    'lat': 50.9404872,
#    'lon': 7.0096049,
#    'tags': {'amenity': 'college',
#     'name': 'Medizinisches Bildungszetrum Kalk',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1026348421,
#    'lat': 50.432252,
#    'lon': 7.6669117,
#    'tags': {'addr:city': 'Höhr-Grenzhausen',
#     'addr:housenumber': '56',
#     'addr:postcode': '56203',
#     'addr:street': 'Rheinstraße',
#     'amenity': 'college',
#     'name': 'Westerwaldcampus FH Koblenz',
#     'official_name': 'FH-Koblenz, Fachbereich'}},
#   {'type': 'node',
#    'id': 1026703443,
#    'lat': 51.6574521,
#    'lon': 7.2415566,
#    'tags': {'addr:city': 'Oer-Erkenschwick',
#     'addr:country': 'DE',
#     'addr:housenumber': '77',
#     'addr:postcode': '45739',
#     'addr:street': 'Haardgrenzweg',
#     'amenity': 'college',
#     'name': 'Salvador-Allende-Haus',
#     'website': 'http://www.allende-haus.de/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1026963588,
#    'lat': 50.4938218,
#    'lon': 12.096283,
#    'tags': {'addr:housenumber': '3',
#     'addr:street': 'Gneisenaustraße',
#     'amenity': 'college',
#     'description': 'Ihr persönlicher Englischtrainer in Plauen',
#     'name': 'Linguama',
#     'website': 'http://linguama.de/'}},
#   {'type': 'node',
#    'id': 1028689268,
#    'lat': 51.031541,
#    'lon': 13.3072001,
#    'tags': {'addr:city': 'Großschirma',
#     'addr:country': 'DE',
#     'addr:housenumber': '4',
#     'addr:postcode': '09603',
#     'addr:street': 'Liebichstraße',
#     'amenity': 'college',
#     'name': 'Meisterschule Orthopädie - Schuhtechnik Siebenlehn'}},
#   {'type': 'node',
#    'id': 1075511336,
#    'lat': 51.4545503,
#    'lon': 7.9596622,
#    'tags': {'amenity': 'college',
#     'name': 'Volkshochschule',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1089121148,
#    'lat': 50.943882,
#    'lon': 7.0100934,
#    'tags': {'amenity': 'college', 'name': 'MedienCampus Nikolaus Gross Haus'}},
#   {'type': 'node',
#    'id': 1123368425,
#    'lat': 53.4716886,
#    'lon': 9.6909875,
#    'tags': {'addr:city': 'Buxtehude',
#     'addr:country': 'DE',
#     'addr:housenumber': '48-50',
#     'addr:postcode': '21614',
#     'addr:street': 'Bahnhofstraße',
#     'alt_name': 'Institut für Berufliche Bildung AG',
#     'amenity': 'college',
#     'email': 'Buxtehude@IBB.com',
#     'name': 'IBB',
#     'phone': '+49 4161 713091',
#     'website': 'http://www.IBB.com'}},
#   {'type': 'node',
#    'id': 1123375412,
#    'lat': 53.2481208,
#    'lon': 10.4464666,
#    'tags': {'alt_name': 'Institut für Berufliche Bildung AG',
#     'amenity': 'college',
#     'email': 'Lueneburg@IBB.com',
#     'name': 'IBB',
#     'phone': '+49 4131 2231498',
#     'website': 'http://www.IBB.com'}},
#   {'type': 'node',
#    'id': 1149799648,
#    'lat': 52.4034046,
#    'lon': 14.5302458,
#    'tags': {'amenity': 'college',
#     'name': 'Landeslehrstätte Lebus - Bruckmühle'}},
#   {'type': 'node',
#    'id': 1157638962,
#    'lat': 53.8450715,
#    'lon': 8.6856572,
#    'tags': {'addr:city': 'Cuxhaven',
#     'addr:country': 'DE',
#     'addr:housenumber': '100',
#     'addr:postcode': '27472',
#     'addr:street': 'Altenwalder Chaussee',
#     'alt_name': 'Institut für Berufliche Bildung AG',
#     'amenity': 'college',
#     'email': 'Cuxhaven@IBB.com',
#     'name': 'IBB',
#     'phone': '+49 4721 398325'}},
#   {'type': 'node',
#    'id': 1229201055,
#    'lat': 51.5276178,
#    'lon': 9.9304349,
#    'tags': {'amenity': 'college',
#     'contact:website': 'http://www.dlr.de/schoollab/desktopdefault.aspx/tabid-1731/11104_read-25323/',
#     'name': 'DLR School Lab'}},
#   {'type': 'node',
#    'id': 1235571322,
#    'lat': 52.6170961,
#    'lon': 13.2471101,
#    'tags': {'amenity': 'college',
#     'contact:phone': '+49 30 387281111',
#     'contact:website': 'https://www.berliner-feuerwehr.de/ueber-uns/ausbildung-an-der-bfra/',
#     'name': 'Berliner Feuerwehr- und Rettungsdienst-Akademie',
#     'operator': 'Berliner Feuerwehr',
#     'short_name': 'BFRA'}},
#   {'type': 'node',
#    'id': 1244882918,
#    'lat': 52.5001131,
#    'lon': 13.4456901,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '4',
#     'addr:postcode': '10997',
#     'addr:street': 'Cuvrystraße',
#     'addr:suburb': 'Kreuzberg',
#     'amenity': 'college',
#     'brand': 'SAE Institute',
#     'brand:wikidata': 'Q201438',
#     'brand:wikipedia': 'en:SAE Institute',
#     'name': 'SAE Institute',
#     'name:de': 'SAE Institute',
#     'phone': '+49 30 43094470'}},
#   {'type': 'node',
#    'id': 1258274412,
#    'lat': 54.3703296,
#    'lon': 10.205931,
#    'tags': {'addr:city': 'Heikendorf',
#     'addr:country': 'DE',
#     'addr:housenumber': '1-3',
#     'addr:postcode': '24226',
#     'addr:street': 'Schulredder',
#     'amenity': 'college',
#     'contact:email': 'info@vhs-heikendorf.de',
#     'contact:fax': '+49 431  23 79 470',
#     'contact:phone': '+49 431  24 51 63',
#     'contact:website': 'http://www.vhs-heikendorf.de',
#     'name': 'Volkshochschule Heikendorf e.V.'}},
#   {'type': 'node',
#    'id': 1286549569,
#    'lat': 52.5500792,
#    'lon': 13.4157651,
#    'tags': {'amenity': 'college',
#     'comment': 'Musikschule',
#     'name': 'Klangbaum',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1300165876,
#    'lat': 49.4192968,
#    'lon': 8.6742803,
#    'tags': {'amenity': 'college',
#     'name': 'Institut für Geowissenschaften',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1300165931,
#    'lat': 49.4188389,
#    'lon': 8.6747178,
#    'tags': {'amenity': 'college',
#     'name': 'Institut für Geowissenschaften',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1345306009,
#    'lat': 48.4795179,
#    'lon': 9.1981112,
#    'tags': {'amenity': 'college',
#     'name': 'Fachschule für Sozialpädagogik',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1348369345,
#    'lat': 53.1456956,
#    'lon': 8.2242181,
#    'tags': {'addr:city': 'Oldenburg',
#     'addr:housenumber': '25',
#     'addr:postcode': '26123',
# ...
#    'tags': {'addr:city': 'Hannover',
#     'addr:housenumber': '17',
#     'addr:postcode': '30163',
#     'addr:street': 'Lister Straße',
#     'alt_name': 'FHM Hannover',
#     'amenity': 'college',
#     'email': 'hannover@fh-mittelstand.de',
#     'fax': '+49 511 53358828',
#     'name': 'Fachhochschule des Mittelstands Hannover',
#     'phone': '+49 511 5335880',
#     'website': 'https://www.fh-mittelstand.de/hannover'}},
#   {'type': 'node',
#    'id': 8308826566,
#    'lat': 52.3746692,
#    'lon': 9.7289616,
#    'tags': {'addr:city': 'Hannover',
#     'addr:housenumber': '18',
#     'addr:postcode': '30169',
#     'addr:street': 'Goethestraße',
#     'amenity': 'college',
#     'email': 'info@gisma.com',
#     'name': 'GISMA Business School Hannover',
#     'phone': '+49 511 54609 0',
#     'website': 'https://www.gisma.com/de/location/study-in-hannover'}},
#   {'type': 'node',
#    'id': 8324412728,
#    'lat': 53.0119969,
#    'lon': 9.0431004,
#    'tags': {'addr:city': 'Achim',
#     'addr:country': 'DE',
#     'addr:housenumber': '26',
#     'addr:postcode': '28832',
#     'addr:street': 'Bergstraße',
#     'amenity': 'college',
#     'name': 'Haus der KVHS',
#     'operator': 'Landkreis Verden',
#     'operator:type': 'public',
#     'phone': '+49 4231 15-160',
#     'website': 'https://www.kvhs-verden.de/'}},
#   {'type': 'node',
#    'id': 8330236508,
#    'lat': 52.4710563,
#    'lon': 13.3238968,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '60',
#     'addr:postcode': '12161',
#     'addr:street': 'Stubenrauchstraße',
#     'addr:suburb': 'Friedenau',
#     'amenity': 'college',
#     'healthcare': 'alternative',
#     'name': 'Heilpraktikerschule Naturheilpraxis',
#     'operator': 'Brigitte Bodammer;Kirill Matveev',
#     'website': 'http://brigitte-bodammer.de;http://www.abcmassage.de'}},
#   {'type': 'node',
#    'id': 8387227243,
#    'lat': 49.9935783,
#    'lon': 8.3994067,
#    'tags': {'alt_name': 'Trainingszentrum',
#     'amenity': 'college',
#     'name': 'Bildungszentrum'}},
#   {'type': 'node',
#    'id': 8388471880,
#    'lat': 48.5294101,
#    'lon': 8.0784984,
#    'tags': {'addr:city': 'Oberkirch',
#     'addr:housenumber': '1',
#     'addr:postcode': '77704',
#     'addr:street': 'Eisenbahnstraße',
#     'amenity': 'college',
#     'name': 'Volkshochschule Ortenau',
#     'website': 'https://www.vhs-ortenau.de/'}},
#   {'type': 'node',
#    'id': 8396646000,
#    'lat': 50.2413133,
#    'lon': 11.3213914,
#    'tags': {'addr:city': 'Kronach',
#     'addr:housenumber': '8',
#     'addr:postcode': '96317',
#     'addr:street': 'Güterstraße',
#     'amenity': 'college',
#     'description': 'Hochschule für angewandte Wissenschaften Coburg - Standort Lucas-Cranach-Campus (LCC)',
#     'email': 'poststelle@hs-coburg.de',
#     'internet_access': 'yes',
#     'internet_access:fee': 'no',
#     'internet_access:ssid': '@BayernWLAN',
#     'name': 'Hochschule für angewandte Wissenschaften Coburg - Lucas-Cranach-Campus',
#     'website': 'https://www.hs-coburg.de',
#     'wikidata': 'Q1622234',
#     'wikipedia': 'de:Hochschule für angewandte Wissenschaften Coburg'}},
#   {'type': 'node',
#    'id': 8397083631,
#    'lat': 49.9793424,
#    'lon': 8.4126192,
#    'tags': {'addr:city': 'Rüsselsheim am Main',
#     'addr:housenumber': '101',
#     'addr:postcode': '65428',
#     'addr:street': 'Darmstädter Straße',
#     'amenity': 'college',
#     'name': 'VHS Unterrichtsstätte Landrat-Harth-Heim',
#     'operator': 'Stadt Rüsselsheim am Main',
#     'operator:type': 'public',
#     'phone': '+49 6142 856875',
#     'website': 'https://kultur123ruesselsheim.de/kultur123/wer-wir-sind/das-team/visitenkarten/vhs-Landrat-Harth-Heim-Liegenschaft-E3520.htm'}},
#   {'type': 'node',
#    'id': 8421612206,
#    'lat': 52.6003732,
#    'lon': 11.8619134,
#    'tags': {'addr:city': 'Stendal',
#     'addr:housenumber': '35',
#     'addr:postcode': '39576',
#     'addr:street': 'Hallstraße',
#     'amenity': 'college',
#     'name': 'Volkshochschule Stendal',
#     'operator': 'Hansestadt Stendal',
#     'operator:type': 'public',
#     'website': 'https://vhs.stendal.de/de/startseite.html'}},
#   {'type': 'node',
#    'id': 8422865842,
#    'lat': 52.4876922,
#    'lon': 13.3323694,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '10715',
#     'addr:street': 'Berliner Straße',
#     'addr:suburb': 'Wilmersdorf',
#     'amenity': 'college',
#     'description': 'Handels- und Sprachenschule; Computerschule',
#     'name': 'Hofmeisterschule',
#     'operator': 'Hofmeisterschule GmbH'}},
#   {'type': 'node',
#    'id': 8477798396,
#    'lat': 51.9717382,
#    'lon': 7.9929759,
#    'tags': {'addr:city': 'Warendorf',
#     'addr:housenumber': '71',
#     'addr:postcode': '48231',
#     'addr:street': 'Dr.-Rau-Allee',
#     'amenity': 'college',
#     'name': 'DEULA Westfalen-Lippe',
#     'operator': 'DEULA Westfalen-Lippe GmbH',
#     'operator:type': 'private',
#     'source': 'local knowledge',
#     'website': 'https://www.deula.de'}},
#   {'type': 'node',
#    'id': 8516373951,
#    'lat': 52.5364627,
#    'lon': 13.2018534,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housenumber': '17',
#     'addr:postcode': '13597',
#     'addr:street': 'Carl-Schurz-Straße',
#     'addr:suburb': 'Spandau',
#     'amenity': 'college',
#     'college': 'adult_education',
#     'contact:phone': '+49 30 902795000',
#     'contact:website': 'https://www.berlin.de/vhs/volkshochschulen/spandau/',
#     'name': 'Harri-Reinert-Volkshochschule Spandau',
#     'name:etymology:wikidata': 'Q96358538',
#     'name:etymology:wikipedia': 'de:Harri Reinert',
#     'operator': 'Bezirksamt Spandau von Berlin, Amt für Weiterbildung und Kultur',
#     'operator:type': 'public'}},
#   {'type': 'node',
#    'id': 8591787124,
#    'lat': 51.3890912,
#    'lon': 7.0810819,
#    'tags': {'addr:city': 'Essen',
#     'addr:housenumber': '3',
#     'addr:postcode': '45257',
#     'addr:street': 'Prinz-Friedrich-Straße',
#     'amenity': 'college',
#     'name': 'maxQ. Essen Pflegeschule',
#     'operator': 'Berufsfortbildungswerk Gemeinnützige Bildungseinrichtung des Deutschen Gewerkschaftsbundes GmbH',
#     'operator:type': 'charitable',
#     'operator:umbrella_organisation': 'Der Paritätische',
#     'website': 'https://www.maxq.net/essen/pflegeschule/'}},
#   {'type': 'node',
#    'id': 8595151487,
#    'lat': 50.9678132,
#    'lon': 7.0111984,
#    'tags': {'addr:city': 'Köln',
#     'addr:housenumber': '28',
#     'addr:postcode': '51063',
#     'addr:street': 'Schanzenstraße',
#     'amenity': 'college',
#     'email': 'info@filmschule.de',
#     'image': 'https://i0.wp.com/www.nicologallio.com/wp-content/uploads/2017/09/ifs-internationale-filmschule-k%C3%B6ln-gmbh.jpg?ssl=1',
#     'name': 'ifs internationale filmschule köln',
#     'operator': 'ifs internationale filmschule köln GmbH',
#     'operator:type': 'private_non_profit',
#     'website': 'https://www.filmschule.de'}},
#   {'type': 'node',
#    'id': 8606418836,
#    'lat': 51.9420538,
#    'lon': 7.6277498,
#    'tags': {'addr:city': 'Münster',
#     'addr:housenumber': '1',
#     'addr:postcode': '48153',
#     'addr:street': 'Höfflingerweg',
#     'amenity': 'college',
#     'name': 'IUBH Internationale Hochschule',
#     'website': 'https://www.iubh-university.de/'}},
#   {'type': 'node',
#    'id': 8653527756,
#    'lat': 52.4372643,
#    'lon': 13.461311,
#    'tags': {'addr:city': 'Berlin',
#     'addr:country': 'DE',
#     'addr:housename': 'P9',
#     'addr:housenumber': '48',
#     'addr:postcode': '12351',
#     'addr:street': 'Rudower Straße',
#     'addr:suburb': 'Buckow',
#     'amenity': 'college',
#     'contact:website': 'https://www.bildungscampus-berlin.de/',
#     'description': 'Standort Süd',
#     'name': 'Berliner Bildungscampus für Gesundheitsberufe',
#     'operator': 'BBG Berliner Bildungscampus für Gesundheitsberufe gGmbH',
#     'short_name': 'BBG'}},
#   {'type': 'node',
#    'id': 8666766274,
#    'lat': 49.5163831,
#    'lon': 8.5315958,
#    'tags': {'amenity': 'college', 'name': 'APH Bildungszentrum'}},
#   {'type': 'node',
#    'id': 8789880547,
#    'lat': 49.7058512,
#    'lon': 9.260442,
#    'tags': {'addr:city': 'Miltenberg',
#     'addr:housenumber': '21',
#     'addr:postcode': '63897',
#     'addr:street': 'Gartenstraße',
#     'amenity': 'college',
#     'isced:level': '7',
#     'name': 'Campus Miltenberg',
#     'operator': 'Technische Hochschule Aschaffenburg',
#     'website': 'https://www.th-ab.de'}},
#   {'type': 'node',
#    'id': 8852350767,
#    'lat': 51.3412897,
#    'lon': 12.3692553,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Dittrichring',
#     'amenity': 'college',
#     'name': 'Hochschule für Musik und Theater Felix Mendelssohn Bartholdy Haus Dittrichring',
#     'website': 'https://www.hmt-leipzig.de/'}},
#   {'type': 'node',
#    'id': 8865087129,
#    'lat': 48.8322783,
#    'lon': 12.9596245,
#    'tags': {'addr:city': 'Deggendorf',
#     'addr:housenumber': '15-19',
#     'addr:postcode': '94469',
#     'addr:street': 'Veilchengasse',
#     'amenity': 'college',
#     'internet_access': 'wlan',
#     'internet_access:ssid': 'Eduroam',
#     'name': 'Fakultät Angewandte Informatik (Außenstelle DEGGs)',
#     'operator': 'Technische Hochschule Deggendorf',
#     'operator:type': 'public',
#     'website': 'https://www.th-deg.de/ai'}},
#   {'type': 'node',
#    'id': 8887201283,
#    'lat': 51.8820207,
#    'lon': 11.0588,
#    'tags': {'addr:city': 'Halberstadt',
#     'addr:housenumber': '14',
#     'addr:postcode': '38820',
#     'addr:street': 'Rudolf-Diesel-Straße',
#     'amenity': 'college',
#     'email': 'info@afu-gmbh.de',
#     'fax': '+49 3941 62 39 35',
#     'name': 'AFU Privates Bildungsinstitut GmbH',
#     'operator': 'AFU Privates  Bildungsinstitut GmbH',
#     'operator:type': 'private',
#     'phone': '+49 3941 60 01 42',
#     'website': 'http://www.afu-gmbh.de/'}},
#   {'type': 'node',
#    'id': 8911758951,
#    'lat': 52.4313892,
#    'lon': 12.5333284,
#    'tags': {'addr:city': 'Brandenburg an der Havel',
#     'addr:housenumber': '25',
#     'addr:postcode': '14772',
#     'addr:street': 'Upstallstraße',
#     'amenity': 'college',
#     'contact:email': 'auskunft@vhs-brandenburg.de',
#     'contact:phone': '+49 3381 5843 10',
#     'contact:website': 'https://www.vhs-brandenburg.de/',
#     'name': 'Volkshochschule',
#     'short_name': 'VHS'}},
#   {'type': 'node',
#    'id': 8915921705,
#    'lat': 48.4686195,
#    'lon': 10.4323822,
#    'tags': {'amenity': 'college',
#     'email': 'millert@sankt-nikolaus.de',
#     'name': 'Berufsschule St. Nikolaus',
#     'phone': '+49 8222 998-360'}},
#   {'type': 'node',
#    'id': 8932488358,
#    'lat': 52.4001223,
#    'lon': 9.8344742,
#    'tags': {'addr:city': 'Hannover',
#     'addr:housenumber': '76',
#     'addr:postcode': '30629',
#     'addr:street': 'Buchholzer Straße',
#     'amenity': 'college',
#     'name': 'Simulations- und Trainingszentrum (SiTZ)',
#     'operator': 'Deutsches Rotes Kreuz Landesverband Niedersachsen e. V.',
#     'operator:type': 'private_non_profit',
#     'website': 'https://www.rettungsschule.de/'}},
#   {'type': 'node',
#    'id': 8977964150,
#    'lat': 51.4796922,
#    'lon': 7.2002272,
#    'tags': {'amenity': 'college',
#     'name': 'Deutsches Anwaltsinstitut Ausbildingscenter',
#     'operator': 'Deutsches Anwaltsinstitut e.V.'}},
#   {'type': 'node',
#    'id': 9007923901,
#    'lat': 49.8816452,
#    'lon': 10.8997534,
#    'tags': {'amenity': 'college',
#     'contact:website': 'https://www.dwbf.de/pflegeschule',
#     'name': 'Evangelische Berufsfachschule für Altenpflege',
#     'operator': 'Caritas-Diakonie Schulträger gGmbH'}},
#   {'type': 'node',
#    'id': 9035411740,
#    'lat': 49.8904761,
#    'lon': 10.8944558,
#    'tags': {'amenity': 'college',
#     'contact:website': 'https://daa-bamberg.de/',
#     'level': '1',
#     'name': 'Deutsche Angestellten-Akademie'}},
#   {'type': 'node',
#    'id': 9035411744,
#    'lat': 49.8903508,
#    'lon': 10.8952752,
#    'tags': {'amenity': 'college',
#     'contact:email': 'info.bamberg@daa.de',
#     'contact:fax': '+49 951 602973-11',
#     'contact:phone': '+49 951 602973-10',
#     'contact:website': 'https://daa-bamberg.de/',
#     'name': 'Deutsche Angestellten-Akademie'}},
#   {'type': 'node',
#    'id': 9043877142,
#    'lat': 53.8228382,
#    'lon': 9.973467,
#    'tags': {'amenity': 'college', 'name': 'DRK Akademie SH'}},
#   {'type': 'node',
#    'id': 9056916893,
#    'lat': 49.30232,
#    'lon': 10.5747831,
#    'tags': {'amenity': 'college',
#     'description': 'Hochschule Ansbach Showroom',
#     'name': 'Pixel Campus',
#     'operator': 'Hochschule Ansbach',
#     'website': 'https://pixel-campus.de/'}},
#   {'type': 'node',
#    'id': 9079753718,
#    'lat': 50.9403893,
#    'lon': 6.9388075,
#    'tags': {'amenity': 'college', 'name': 'Anadolu Universität'}},
#   {'type': 'node',
#    'id': 9083510561,
#    'lat': 48.8109974,
#    'lon': 13.5469713,
#    'tags': {'addr:city': 'Freyung',
#     'addr:country': 'DE',
#     'addr:housenumber': '22',
#     'addr:postcode': '94078',
#     'addr:street': 'Grafenauer Straße',
#     'amenity': 'college',
#     'name': 'Technologie Campus Freyung',
#     'operator': 'Technische Hochschule Deggendorf',
#     'operator:type': 'public'}},
#   {'type': 'node',
#    'id': 9104001346,
#    'lat': 53.567057,
#    'lon': 10.0003703,
#    'tags': {'amenity': 'college',
#     'contact:email': 'hamburg@amdnet.de',
#     'contact:phone': '+49 40 237878-0',
#     'contact:website': 'https://www.amdnet.de/',
#     'name': 'AMD Akademie Mode & Design'}},
#   {'type': 'node',
#    'id': 9123087861,
#    'lat': 51.19291,
#    'lon': 6.4318814,
#    'tags': {'amenity': 'college',
#     'description': 'ZfsL = Zentrum für schulpraktische Lehrerausbildung (Mönchengladbach)',
#     'name': 'ZfsL',
#     'operator': 'Ministerium für Schule und Weiterbildung NRW',
#     'website': 'https://www.zfsl.nrw.de/MGL/'}},
#   {'type': 'node',
#    'id': 9144262182,
#    'lat': 47.6649836,
#    'lon': 9.4468928,
#    'tags': {'amenity': 'college',
#     'name': 'DHBW',
#     'opening_hours': 'Mo-Fr 07:00-17:00'}},
#   {'type': 'node',
#    'id': 9167919359,
#    'lat': 48.0661365,
#    'lon': 8.4441246,
#    'tags': {'addr:city': 'Villingen-Schwenningen',
#     'addr:postcode': '78048',
#     'addr:street': 'Peterzeller Straße',
#     'amenity': 'college',
#     'contact:email': 'akademie@vs.ihk.de',
#     'contact:phone': '+49 7721 922-313',
#     'email': 'akademie@vs.ihk.de',
#     'name': 'IHK Akademie',
#     'note': '"Während Universitäten als vollumfängliche Hochschulen mit Promotionsrecht definiert sind, ist ein College in dem hier beschriebenen Sinn eine Einrichtung, die zwar berufsqualifierende, aber keine höheren akademischen Abschlüsse anbietet." - Wiki',
#     'operator': 'IHK Schwarzwald-Baar-Heuberg',
#     'phone': '+49 7721 922-313',
#     'website': 'https://www.ihkakademie-sbh.de'}},
#   {'type': 'node',
#    'id': 9177030961,
#    'lat': 48.1321508,
#    'lon': 11.6289644,
#    'tags': {'amenity': 'college',
#     'description': 'Berufsfachschule für Innenarchitektur und Kommunikationsdesign',
#     'email': 'kontakt@blochererschule.de',
#     'fax': '+49 89 48 54 52',
#     'name': 'Blocherer Schule',
#     'phone': '+49 89 48 84 24',
#     'website': 'https://www.blochererschule.de/'}},
#   {'type': 'node',
#    'id': 9227254546,
#    'lat': 53.6028345,
#    'lon': 10.0238735,
#    'tags': {'addr:city': 'Hamburg',
#     'addr:country': 'DE',
#     'addr:housenumber': '9',
#     'addr:postcode': '22297',
#     'addr:street': 'Überseering',
#     'amenity': 'college',
#     'brand': 'Heinze Akademie',
#     'brand:wikidata': 'Q2399069',
#     'brand:wikipedia': 'de:Heinze Akademie',
#     'contact:email': 'info@heinze-akademie.de',
#     'contact:phone': '0406390290',
#     'name': 'Heinze Akademie für Technik und Design',
#     'website': 'https://www.heinze-akademie.de/'}},
#   {'type': 'node',
#    'id': 9244450820,
#    'lat': 51.4277833,
#    'lon': 6.8842221,
#    'tags': {'amenity': 'college',
#     'name': 'Beauty Hair Company',
#     'website': 'https://www.beautyhaircompany.de'}},
#   {'type': 'node',
#    'id': 9250144630,
#    'lat': 53.8940514,
#    'lon': 11.4757788,
#    'tags': {'addr:city': 'Wismar',
#     'addr:housenumber': '5b',
#     'addr:postcode': '23970',
#     'addr:street': 'Gerberhof',
#     'amenity': 'college',
#     'name': 'Pädagogisches Forum',
#     'operator': 'LernWert gemeinnützige GmbH',
#     'operator:type': 'private_non_profit',
#     'website': 'https://lernwert-wismar.de/'}}]}

# %% [markdown]
# # Parking Station

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="parking_entrance"](area);
 way["amenity"="parking_entrance"](area);
 rel["amenity"="parking_entrance"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_parking_entrance = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_parking_entrance['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('bus_stop in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
len(X)
# Out:
# 18687

# %% [markdown]
# # Hospital

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="hospital"](area);
 way["amenity"="hospital"](area);
 rel["amenity"="hospital"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_hospital = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_hospital['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('bus_stop in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
len(X)
# Out:
# 339

# %% [markdown]
# # Random

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="company"](area);
 way["amenity"="company"](area);
 rel["amenity"="company"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_ = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('bus_stop in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
len(X)
# Out:
# 8

# %% [markdown]
# # Biergarten

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="biergarten"](area);
 way["amenity"="biergarten"](area);
 rel["amenity"="biergarten"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_biergarten = response.json()

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.57 93a4d346',
#  'osm3s': {'timestamp_osm_base': '2021-11-23T18:24:35Z',
#   'timestamp_areas_base': '2021-11-23T16:17:53Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 30635438,
#    'lat': 48.8118147,
#    'lon': 11.8560244,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 61209400,
#    'lat': 49.2128911,
#    'lon': 8.5285651,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref_name': 'Wiesental Einkaufszentrum',
#     'uic_name': 'Wiesental Einkaufszentrum, Waghäusel',
#     'uic_ref': '722698',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 261110113,
#    'lat': 51.1555427,
#    'lon': 6.6942832,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'local_ref': '2',
#     'name': 'Einkaufszentrum',
#     'network': 'VRR',
#     'operator': 'Stadtwerke Neuss GmbH',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:5162:20421:1:2',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 261110122,
#    'lat': 51.1555226,
#    'lon': 6.6940538,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'local_ref': '1',
#     'name': 'Einkaufszentrum',
#     'network': 'VRR',
#     'operator': 'Stadtwerke Neuss GmbH',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:5162:20421:1:1',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 307198115,
#    'lat': 50.97138,
#    'lon': 11.0566858,
#    'tags': {'name': 'Einkaufszentrum',
#     'operator': 'EVAG',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 313201164,
#    'lat': 48.6879383,
#    'lon': 9.0092501,
#    'tags': {'amenity': 'parking',
#     'name': 'Einkaufszentrum',
#     'parking': 'multi-storey',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 325753390,
#    'lat': 50.9924527,
#    'lon': 8.2564394,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'Bürgerbus Erndtebrück e. V.'}},
#   {'type': 'node',
#    'id': 331026685,
#    'lat': 52.2077596,
#    'lon': 10.3031532,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VRB',
#     'shelter': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 331026687,
#    'lat': 52.2081347,
#    'lon': 10.3031124,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VRB'}},
#   {'type': 'node',
#    'id': 332055672,
#    'lat': 51.4180499,
#    'lon': 6.7095499,
#    'tags': {'bench': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'ref_name': 'Einkaufszentrum, Duisburg',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 335520593,
#    'lat': 50.9709757,
#    'lon': 11.056848,
#    'tags': {'name': 'Einkaufszentrum', 'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 366863322,
#    'lat': 51.7664843,
#    'lon': 6.3809195,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 366899380,
#    'lat': 51.229963,
#    'lon': 7.8700691,
#    'tags': {'bus': 'yes',
#     'fixme': 'genaue Position?',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref:IFOPT': 'de:05962:2974',
#     'ref_name': 'Plettenberg, Einkaufszentrum'}},
#   {'type': 'node',
#    'id': 386043642,
#    'lat': 49.8929095,
#    'lon': 8.6077198,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'stop_position',
#     'ref_name': 'Riedbahn Einkaufszentrum, Weiterstadt',
#     'shelter': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 516507126,
#    'lat': 52.4760472,
#    'lon': 9.7974577,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'lit': 'no',
#     'name': 'Einkaufszentrum',
#     'network': 'GVH',
#     'shelter': 'yes',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 527833431,
#    'lat': 50.8410391,
#    'lon': 8.7686198,
#    'tags': {'bench': 'yes',
#     'bin': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'seats': '2',
#     'shelter': 'yes',
#     'tactile_paving': 'no',
#     'waste_basket': 'no',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 527833432,
#    'lat': 50.840537,
#    'lon': 8.7670586,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'check_date:shelter': '2021-06-14',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'seats': '4',
#     'shelter': 'yes',
#     'tactile_paving': 'no',
#     'waste_basket': 'yes',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 576223021,
#    'lat': 51.4183501,
#    'lon': 6.7095577,
#    'tags': {'bench': 'no',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'ref_name': 'Einkaufszentrum, Duisburg',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 652813441,
#    'lat': 49.8917763,
#    'lon': 8.6074935,
#    'tags': {'amenity': 'taxi', 'name': 'Einkaufszentrum'}},
#   {'type': 'node',
#    'id': 662275158,
#    'lat': 51.3677791,
#    'lon': 9.3992586,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Nordhessischer VerkehrsVerbund',
#     'ref': '710161',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 664456631,
#    'lat': 51.1275062,
#    'lon': 13.9164929,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RBO',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:14625:6736',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 664456632,
#    'lat': 51.1278751,
#    'lon': 13.9167937,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RBO',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:14625:6736',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 683652191,
#    'lat': 48.8056928,
#    'lon': 9.0765878,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'fee_zone': '2',
#     'highway': 'bus_stop',
#     'lines': '635',
#     'name': 'Einkaufszentrum',
#     'network': 'VVS',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 683652192,
#    'lat': 48.8059752,
#    'lon': 9.0769773,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'fee_zone': '2',
#     'lines': '635',
#     'name': 'Einkaufszentrum',
#     'network': 'VVS',
#     'public_transport': 'platform',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 696935867,
#    'lat': 54.4123543,
#    'lon': 10.2857473,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 738003693,
#    'lat': 53.5600351,
#    'lon': 7.9152503,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VEJ',
#     'public_transport': 'platform',
#     'shelter': 'no',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 738003740,
#    'lat': 53.5600103,
#    'lon': 7.9155192,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VEJ',
#     'public_transport': 'platform',
#     'shelter': 'no',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 738003744,
#    'lat': 53.5600216,
#    'lon': 7.9153694,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 798095604,
#    'lat': 54.3051076,
#    'lon': 9.5866134,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'Autokraft',
#     'public_transport': 'platform',
#     'route_ref': '2'}},
#   {'type': 'node',
#    'id': 967013701,
#    'lat': 52.4142019,
#    'lon': 10.8394834,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Region Braunschweig',
#     'operator': 'Wolfsburger Verkehrs-GmbH',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 986022801,
#    'lat': 47.5658144,
#    'lon': 8.0733887,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'ele': '318',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'WTV',
#     'operator': 'SBG',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:08337:4662',
#     'shelter': 'yes',
#     'source': 'Bundesamt für Verkehr (BAV), DIDOK 2009',
#     'uic_name': 'Laufenburg [D], Einkaufszentr.',
#     'uic_ref': '8587396',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1139503279,
#    'lat': 48.8059455,
#    'lon': 9.0769994,
#    'tags': {'bus': 'yes',
#     'fee_zone': '2',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VVS',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 1236571899,
#    'lat': 51.6057126,
#    'lon': 14.4104204,
#    'tags': {'addr:housenumber': '8',
#     'addr:postcode': '03130',
#     'addr:street': 'Straße der Einheit',
#     'name': 'Einkaufszentrum',
#     'shop': 'supermarket'}},
#   {'type': 'node',
#    'id': 1240843563,
#    'lat': 51.7669672,
#    'lon': 6.3801279,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 1417555379,
#    'lat': 50.9108397,
#    'lon': 13.3937149,
#    'tags': {'name': 'Einkaufszentrum', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 1449004709,
#    'lat': 54.2949521,
#    'lon': 9.7079518,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 1832183661,
#    'lat': 52.4099346,
#    'lon': 12.6112667,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1850683073,
#    'lat': 47.5658961,
#    'lon': 8.0735685,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref:IFOPT': 'de:08337:4662'}},
#   {'type': 'node',
#    'id': 1889179262,
#    'lat': 53.0025138,
#    'lon': 11.7227237,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'lit': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1889180096,
#    'lat': 53.0025527,
#    'lon': 11.7226165,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 2320757756,
#    'lat': 50.9793906,
#    'lon': 13.85355,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RVSOE',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:14628:3072',
#     'shelter': 'yes',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 2358957927,
#    'lat': 51.2880874,
#    'lon': 13.4942935,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Oberelbe',
#     'operator': 'Verkehrsgesellschaft Meißen',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:14627:5095',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 2388178021,
#    'lat': 51.4416752,
#    'lon': 14.0994516,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref_name': 'Einkaufszentrum, Torno'}},
#   {'type': 'node',
#    'id': 2912110112,
#    'lat': 50.6472924,
#    'lon': 11.4516093,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'lit': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 2912110119,
#    'lat': 50.647597,
#    'lon': 11.4513746,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'lit': 'no',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'no'}},
#   {'type': 'node',
#    'id': 2955914206,
#    'lat': 52.4140125,
#    'lon': 10.8399624,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Region Braunschweig',
#     'operator': 'Wolfsburger Verkehrs-GmbH',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 2992793252,
#    'lat': 51.3041061,
#    'lon': 7.1064642,
#    'tags': {'fixme': 'Position prüfen.',
#     'highway': 'bus_stop',
#     'mapillary': '6ashYvLDHfP_qq8XrGy9sg',
#     'name': 'Einkaufszentrum',
#     'pole': 'yes',
#     'public_transport': 'stop_position',
#     'shelter': 'no',
#     'survey:date': '2020-04-21'}},
#   {'type': 'node',
#    'id': 3089181980,
#    'lat': 51.0215743,
#    'lon': 8.6625883,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'NVV',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 3099383330,
#    'lat': 51.3225351,
#    'lon': 9.1801982,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'NVV'}},
#   {'type': 'node',
#    'id': 3184041696,
#    'lat': 51.0659545,
#    'lon': 13.8955333,
#    'tags': {'bench': 'no',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RBO',
#     'public_transport': 'platform',
#     'ref': '3',
#     'ref:IFOPT': 'de:14612:3781',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Rampe erforderlich'}},
#   {'type': 'node',
#    'id': 3283463416,
#    'lat': 52.4098773,
#    'lon': 12.6111992,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 3405461946,
#    'lat': 49.2125785,
#    'lon': 8.5289028,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref_name': 'Wiesental Einkaufszentrum',
#     'uic_name': 'Wiesental Einkaufszentrum, Waghäusel',
#     'uic_ref': '722698',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3437215208,
#    'lat': 52.4142393,
#    'lon': 10.839509,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Region Braunschweig',
#     'operator': 'Wolfsburger Verkehrs-GmbH',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 3454224323,
#    'lat': 51.0658137,
#    'lon': 13.8955909,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RBO',
#     'public_transport': 'platform',
#     'ref': '1',
#     'ref:IFOPT': 'de:14612:3781',
#     'shelter': 'no',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Rampe erforderlich'}},
#   {'type': 'node',
#    'id': 3505917752,
#    'lat': 51.7897141,
#    'lon': 6.0120714,
#    'tags': {'bus': 'yes',
#     'fixme': 'Lage geschätzt',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 3518195505,
#    'lat': 50.7093589,
#    'lon': 8.6954367,
#    'tags': {'bench': 'no',
#     'bin': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 3518195506,
#    'lat': 50.7093817,
#    'lon': 8.6952655,
#    'tags': {'bench': 'no',
#     'bin': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 3726297339,
#    'lat': 51.4181159,
#    'lon': 6.7097019,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 3726297340,
#    'lat': 51.4183069,
#    'lon': 6.7094497,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 3753308153,
#    'lat': 51.0215234,
#    'lon': 8.662743,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'NVV',
#     'public_transport': 'platform',
#     'shelter': 'yes',
#     'tactile_paving': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 4108307076,
#    'lat': 51.1554936,
#    'lon': 6.6941686,
#    'tags': {'bus': 'yes',
#     'local_ref': '2',
#     'name': 'Einkaufszentrum',
#     'network': 'VRR',
#     'operator': 'Stadtwerke Neuss GmbH',
#     'public_transport': 'stop_position',
#     'ref:IFOPT': 'de:5162:20421:1:2'}},
#   {'type': 'node',
#    'id': 4108307077,
#    'lat': 51.1555423,
#    'lon': 6.6941264,
#    'tags': {'bus': 'yes',
#     'local_ref': '1',
#     'name': 'Einkaufszentrum',
#     'network': 'VRR',
#     'operator': 'Stadtwerke Neuss GmbH',
#     'public_transport': 'stop_position',
#     'ref:IFOPT': 'de:5162:20421:1:1'}},
#   {'type': 'node',
#    'id': 4491223822,
#    'lat': 51.2881861,
#    'lon': 13.4942758,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Oberelbe',
#     'operator': 'Verkehrsgesellschaft Meißen',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:14627:5095',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 4683766190,
#    'lat': 49.7694818,
#    'lon': 11.0355801,
#    'tags': {'bench': 'no',
#     'bin': 'no',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VGN',
#     'public_transport': 'platform',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 4713497362,
#    'lat': 50.840462,
#    'lon': 8.767134,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 4847919421,
#    'lat': 48.9204795,
#    'lon': 11.8819553,
#    'tags': {'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 4847919422,
#    'lat': 48.920453,
#    'lon': 11.8821591,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'covered': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 4884181849,
#    'lat': 48.8116681,
#    'lon': 11.85619,
#    'tags': {'name': 'Einkaufszentrum', 'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 4884181850,
#    'lat': 48.8119613,
#    'lon': 11.8558681,
#    'tags': {'name': 'Einkaufszentrum', 'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 5271836730,
#    'lat': 54.4123781,
#    'lon': 10.2858155,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 5453445284,
#    'lat': 52.3146263,
#    'lon': 7.8719012,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:05566:65536:0:1'}},
#   {'type': 'node',
#    'id': 5453445285,
#    'lat': 52.3145886,
#    'lon': 7.8719039,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position',
#     'ref:IFOPT': 'de:05566:65536:0:1'}},
#   {'type': 'node',
#    'id': 6030903749,
#    'lat': 51.322069,
#    'lon': 9.180261,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 6030903750,
#    'lat': 51.3221133,
#    'lon': 9.1802946,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'ref_name': 'Einkaufszentrum, Wolfhagen'}},
#   {'type': 'node',
#    'id': 6030903752,
#    'lat': 51.3220975,
#    'lon': 9.1802094,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 6030903753,
#    'lat': 51.3220357,
#    'lon': 9.1801478,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'ref_name': 'Einkaufszentrum, Wolfhagen'}},
#   {'type': 'node',
#    'id': 6512750295,
#    'lat': 51.203129,
#    'lon': 7.1303245,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'operator': 'Bürgerbus Cronenberg',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 6705168191,
#    'lat': 48.8632988,
#    'lon': 10.3411103,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'OstalbMobil',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 6786289750,
#    'lat': 52.4140508,
#    'lon': 10.8399969,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Region Braunschweig',
#     'operator': 'Wolfsburger Verkehrs-GmbH',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 7301627365,
#    'lat': 49.7694623,
#    'lon': 11.0355923,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 7701867038,
#    'lat': 48.6790943,
#    'lon': 9.7617549,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform',
#     'traffic_sign': 'DE:224'}},
#   {'type': 'node',
#    'id': 7769636802,
#    'lat': 48.5737819,
#    'lon': 8.766768,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'fee_zone': '5',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VVS',
#     'public_transport': 'platform',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 7769636803,
#    'lat': 48.5739168,
#    'lon': 8.7668109,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'fee_zone': '5',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VVS',
#     'public_transport': 'platform',
#     'shelter': 'no'}},
#   {'type': 'node',
#    'id': 7823898456,
#    'lat': 54.3049926,
#    'lon': 9.5866213,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'Autokraft',
#     'public_transport': 'platform',
#     'route_ref': '2'}},
#   {'type': 'node',
#    'id': 7825918609,
#    'lat': 54.2950158,
#    'lon': 9.7078775,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 7829045039,
#    'lat': 50.1592717,
#    'lon': 7.1812257,
#    'tags': {'bench': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'Verkehrsverbund Rhein-Mosel',
#     'operator': 'Omnibusverkehr Eifel',
#     'operator:short': 'OVEM',
#     'public_transport': 'platform',
#     'shelter': 'yes'}},
#   {'type': 'node',
#    'id': 8158369327,
#    'lat': 48.088125,
#    'lon': 10.0776212,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'operator': 'Bayer Reisen',
#     'public_transport': 'platform',
#     'ref:IFOPT': 'de:08426:6726',
#     'shelter': 'np'}},
#   {'type': 'node',
#    'id': 8259270705,
#    'lat': 52.9898231,
#    'lon': 7.627607,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 8259270706,
#    'lat': 52.9895365,
#    'lon': 7.6269981,
#    'tags': {'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'platform'}},
#   {'type': 'node',
#    'id': 8259270707,
#    'lat': 52.9894893,
#    'lon': 7.6271041,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 8259270708,
#    'lat': 52.9898566,
#    'lon': 7.6275279,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 8575059025,
#    'lat': 51.0656723,
#    'lon': 13.8958252,
#    'tags': {'bench': 'yes',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'operator': 'RBO',
#     'public_transport': 'platform',
#     'ref': '1',
#     'ref:IFOPT': 'de:14612:3781',
#     'shelter': 'no',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Rampe erforderlich'}},
#   {'type': 'node',
#    'id': 8698904651,
#    'lat': 50.5386151,
#    'lon': 8.7537123,
#    'tags': {'bench': 'no',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'ref_name': 'Garbenteich Einkaufszentrum, Pohlheim',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'waste_basket': 'yes',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 8698904652,
#    'lat': 50.5385631,
#    'lon': 8.7539028,
#    'tags': {'bench': 'no',
#     'bin': 'yes',
#     'bus': 'yes',
#     'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'RMV',
#     'public_transport': 'platform',
#     'ref_name': 'Garbenteich Einkaufszentrum, Pohlheim',
#     'shelter': 'no',
#     'tactile_paving': 'no',
#     'waste_basket': 'yes',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Kein Kasseler Bord'}},
#   {'type': 'node',
#    'id': 8723438885,
#    'lat': 50.5386264,
#    'lon': 8.7538116,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 8723438886,
#    'lat': 50.5385564,
#    'lon': 8.753847,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 8963784902,
#    'lat': 48.9204695,
#    'lon': 11.8820283,
#    'tags': {'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'network': 'RBO;VLK;LAVV',
#     'public_transport': 'stop_position'}},
#   {'type': 'node',
#    'id': 9008368772,
#    'lat': 49.5679731,
#    'lon': 8.7089831,
#    'tags': {'highway': 'bus_stop',
#     'name': 'Einkaufszentrum',
#     'network': 'VRN',
#     'public_transport': 'platform',
#     'share_taxi': 'yes'}},
#   {'type': 'node',
#    'id': 9159429145,
#    'lat': 48.7013846,
#    'lon': 10.2350374,
#    'tags': {'highway': 'bus_stop', 'name': 'Einkaufszentrum'}},
#   {'type': 'node',
#    'id': 9159429146,
#    'lat': 48.7012629,
#    'lon': 10.2349392,
#    'tags': {'highway': 'bus_stop', 'name': 'Einkaufszentrum'}},
#   {'type': 'node',
#    'id': 9228615975,
#    'lat': 48.694705,
#    'lon': 10.0717485,
#    'tags': {'bench': 'no',
#     'bus': 'yes',
#     'name': 'Einkaufszentrum',
#     'network': 'Heidenheimer Tarifverbund',
#     'operator': 'Heidenheimer Verkehrsgesellschaft',
#     'operator:short': 'HVG',
#     'public_transport': 'platform',
#     'shelter': 'no'}}]}

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_biergarten['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Biergarten in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
import overpy
api = overpy.Overpass()
result = api.query("""node["name"="Buro"];out body;""")
len(result.nodes)
# Out:
# 15

# %% [markdown]
# # Kino in Germany

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="cinema"](area);
 way["amenity"="cinema"](area);
 rel["amenity"="cinema"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_cinema = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_cinema['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], '*')
plt.title('Kino(Cinema) in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Office in Germany

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="office"](area);
 way["amenity"="office"](area);
 rel["amenity"="office"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], 'o')
plt.title('Office in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Restuarnt

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="restaurant"](area);
 way["amenity"="restaurant"](area);
 rel["amenity"="restaurant"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], '*')
plt.title('Restaurant in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # cafe

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["amenity"="cafe"](area);
 way["amenity"="cafe"](area);
 rel["amenity"="cafe"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data_cafe = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data_cafe['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], '*')
plt.title('cafe in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Shopping centre

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["name"="Einkaufszentrum"](area);
 way["name"="Einkaufszentrum"](area);
 rel["name"="Einkaufszentrum"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], '*')
plt.title('shopping centre in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %% [markdown]
# # supermarket

# %%
import requests
import json
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
[out:json];
area["ISO3166-1"="DE"][admin_level=2];
(node["name"="Supermarkt"](area);
 way["name"="Supermarkt"](area);
 rel["name"="Supermarkt"](area);
);
out center;
"""
response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Collect coords into list
coords = []
for element in data['elements']:
    if element['type'] == 'node':
        lon = element['lon']
        lat = element['lat']
        coords.append((lon, lat))
    elif 'center' in element:
        lon = element['center']['lon']
        lat = element['center']['lat']
        coords.append((lon, lat))
# Convert coordinates into numpy array
X = np.array(coords)
plt.plot(X[:, 0], X[:, 1], '*')
plt.title('Supermarket in Germany')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()
